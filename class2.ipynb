# %% [markdown]
# # Operators in Python
#  ## -Arithmetic Operators
#  ## -Relational Operators
# ## -Logical Operators
# ## -Bitwise Operators
# ## -Assignment Operators
# ## -Membership Operators

# %%
 #Arithmetric Operators
print(5+6)

print(5-6)

print(5*6)

print(5/2)

print(5//2)

print(5%2)

print(5**2)
# Out:
# 11
# -1
# 30
# 2.5
# 2
# 1
# 25

# %%
# Relational Operators
print(4>5)

print(4<5)

print(4>=4)

print(4<=4)

print(4==4)

print(4!=4)
# Out:
# False
# True
# True
# True
# True
# False

# %%
# Logical Operators
print(1 and 0)

print(1 or 0)

print(not 1)
# Out:
# 0
# 1
# False

# %%
# Bitwise Operators

# bitwise and
print(2 & 3)

# bitwise or
print(2 | 3)

# bitwise xor
print(2 ^ 3)

print(~3)

print(4 >> 2)

print(5 << 2)
# Out:
# 2
# 3
# 1
# -4
# 1
# 20

# %%
# Assignment Operators

# = 
# a = 2

a = 2

# a = a % 2
a %= 2

# a++ ++a

print(a)
# Out:
# 0

# %%
# Membership Operators

# in/not in

print('D' not in 'Delhi')

print(1 in [2,3,4,5,6])
# Out:
# False
# False

# %%
# Program - Find the sum of a 3 digit number entered by the user

number = int(input('Enter a 3 digit number'))

# 345%10 -> 5
a = number%10

number = number//10

# 34%10 -> 4
b = number % 10

number = number//10
# 3 % 10 -> 3
c = number % 10

print(a + b + c)
# Out:
# Enter a 3 digit number 456
# 15

# %% [markdown]
#  # If-else in Python

# %%
# login program and indentation
# email -> nitish.campusx@gmail.com
# password -> 1234

email = input('enter email')
password = input('enter password')

if email == 'nitish.campusx@gmail.com' and password == '1234':
  print('Welcome')
elif email == 'nitish.campusx@gmail.com' and password != '1234':
  # tell the user
  print('Incorrect password')
  password = input('enter password again')
  if password == '1234':
    print('Welcome,finally!')
  else:
    print('beta tumse na ho paayega!')
else:
  print('Not correct')
# Out:
# enter email sharjeel@gamil.com
# enter password 1234
# Not correct

# %%
# if-else examples
# 1. Find the min of 3 given numbers
# 2. Menu Driven Program

# %%
# min of 3 number

a = int(input('first num'))
b = int(input('second num'))
c = int(input('third num'))

if a<b and a<c:
  print('smallest is',a)
elif b<c:
  print('smallest is',b)
else:
  print('smallest is',c)
# Out:
# first num 2
# second num 4
# third num 4
# smallest is 2

# %%
# menu driven calculator
menu = input("""
Hi! how can I help you.
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for withdrawl
4. Enter 4 for exit
""")

if menu == '1':
  print('pin change')
elif menu == '2':
  print('balance')
else:
  print('exit')
# Out:
# Hi! how can I help you.
# 1. Enter 1 for pin change
# 2. Enter 2 for balance check
# 3. Enter 3 for withdrawl
# 4. Enter 4 for exit
#  2
# balance

# %% [markdown]
# # Modules in Python

# %%
# - math
# - keywords
# - random
# - datetime

# %%
# math
import math

math.sqrt(196)
# Out:
# 14.0

# %%
# keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 39

# %%
# datetime
import datetime
print(datetime.datetime.now())
# Out:
# 2025-11-11 20:08:06.661843

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Alpha-tech\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\Users\Alpha-tech\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# C:\Users\Alpha-tech\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# C:\Users\Alpha-tech\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\Alpha-tech\anaconda3\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# C:\Users\Alpha-tech\anaconda3\Lib\pkgutil.py:78: FutureWarning: The 'optree.integration' module is deprecated and will be removed in version 0.18.0. Please use 'optree.integrations' instead.
#   __import__(info.name)
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# C:\Users\Alpha-tech\anaconda3\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# 3204bda914b7f2c6f497__mypyc conda               mistune             sndhdr
# IPython             conda_build         mkl                 sniffio
# OpenSSL             conda_content_trust mkl_fft             snowballstemmer
# PIL                 conda_env           mkl_random          socket
# PyQt5               conda_index         ml_dtypes           socketserver
# __future__          conda_libmamba_solver mmap                socks
# __hello__           conda_pack          mmapfile            sockshandler
# __phello__          conda_package_handling mmsystem            sortedcontainers
# _abc                conda_package_streaming modulefinder        soupsieve
# _aix_support        conda_token         more_itertools      sphinx
# _argon2_cffi_bindings configparser        mpmath              spyder
# _ast                constantly          msgpack             spyder_kernels
# _asyncio            contextlib          msilib              sqlalchemy
# _bisect             contextvars         msvcrt              sqlite3
# _black_version      contourpy           multidict           sre_compile
# _blake2             cookiecutter        multimethod         sre_constants
# _brotli             copy                multipledispatch    sre_parse
# _bz2                copyreg             multiprocessing     ssl
# _cffi_backend       cpuinfo             multitasking        sspi
# _codecs             crypt               mypy                sspicon
# _codecs_cn          cryptography        mypy_extensions     stack_data
# _codecs_hk          cssselect           mypyc               stat
# _codecs_iso2022     csv                 nacl                statistics
# _codecs_jp          ctypes              namex               statsmodels
# _codecs_kr          curl                navigator_updater   streamlit
# _codecs_tw          curl_cffi           nbclient            string
# _collections        curses              nbconvert           stringprep
# _collections_abc    cwp                 nbformat            struct
# _compat_pickle      cycler              nest_asyncio        subprocess
# _compression        cytoolz             netbios             sunau
# _contextvars        dacite              netrc               sympy
# _csv                dask                networkx            symtable
# _ctypes             dask_expr           nltk                sys
# _ctypes_test        dataclasses         nntplib             sysconfig
# _datetime           datashader          notebook            tables
# _decimal            datetime            notebook_shim       tabnanny
# _distutils_hack     dateutil            nt                  tabulate
# _elementtree        dbi                 ntpath              tangled_up_in_unicode
# _functools          dbm                 ntsecuritycon       tarfile
# _hashlib            dde                 nturl2path          tblib
# _heapq              debugpy             numba               telnetlib
# _imp                decimal             numbergen           tempfile
# _io                 decorator           numbers             tenacity
# _json               defusedxml          numexpr             tensorboard
# _locale             diff_match_patch    numpy               tensorboard_data_server
# _lsprof             difflib             numpydoc            tensorflow
# _lzma               dill                odbc                termcolor
# _markupbase         dis                 opcode              terminado
# _md5                distributed         openpyxl            test
# _msi                distro              operator            test_pycosat
# _multibytecodec     docstring_to_markdown opt_einsum          text_unidecode
# _multiprocessing    doctest             optparse            textdistance
# _nsis               docutils            optree              textwrap
# _opcode             dotenv              os                  this
# _operator           email               overrides           threading
# _osx_support        encodings           packaging           threadpoolctl
# _overlapped         ensurepip           pandas              three_merge
# _pickle             enum                pandas_profiling    tifffile
# _plotly_future_     erfa                pandocfilters       time
# _plotly_utils       errno               panel               timeit
# _py_abc             et_xmlfile          param               timer
# _pydatetime         executing           paramiko            tinycss2
# _pydecimal          fastjsonschema      parsel              tkinter
# _pyio               faulthandler        parso               tldextract
# _pylong             filecmp             partd               tlz
# _pytest             fileinput           pasta               token
# _queue              filelock            pathlib             tokenize
# _random             filetype            pathspec            toml
# _ruamel_yaml        flake8              patsy               tomli
# _sha1               flask               pdb                 tomlkit
# _sha2               flatbuffers         peewee              tomllib
# _sha3               fnmatch             perfmon             toolz
# _signal             fontTools           pexpect             tornado
# _sitebuiltins       fractions           phik                tqdm
# _socket             frozendict          pickle              trace
# _sqlite3            frozenlist          pickleshare         traceback
# _sre                fsspec              pickletools         tracemalloc
# _ssl                ftplib              pip                 traitlets
# _stat               functools           pipes               truststore
# _statistics         gast                pkce                tty
# _string             gc                  pkg_resources       turtle
# _strptime           genericpath         pkginfo             turtledemo
# _struct             gensim              pkgutil             twisted
# _symtable           getopt              platform            typeguard
# _system_path        getpass             platformdirs        types
# _testbuffer         gettext             playhouse           typing
# _testcapi           git                 plistlib            typing_extensions
# _testclinic         gitdb               plotly              tzdata
# _testconsole        glob                pluggy              uc_micro
# _testimportmultiple graphlib            ply                 ujson
# _testinternalcapi   greenlet            poplib              unicodedata
# _testmultiphase     grpc                posixpath           unicodedata2
# _testsinglephase    gzip                pprint              unidecode
# _thread             h11                 profile             unittest
# _threading_local    h5py                prometheus_client   urllib
# _tkinter            hashlib             prompt_toolkit      urllib3
# _tokenize           heapdict            protego             uu
# _tracemalloc        heapq               pstats              uuid
# _typing             hmac                psutil              venv
# _uuid               holoviews           pty                 visions
# _warnings           html                ptyprocess          w3lib
# _weakref            htmlmin             pure_eval           warnings
# _weakrefset         http                puremagic           watchdog
# _win32sysloader     httpcore            pwiz                wave
# _winapi             httpx               py                  wcwidth
# _winxptheme         hvplot              py_compile          weakref
# _wmi                hyperlink           pyarrow             webbrowser
# _xxinterpchannels   idlelib             pyasn1              webencodings
# _xxsubinterpreters  idna                pyasn1_modules      websocket
# _yaml               imagecodecs         pyclbr              websockets
# _zoneinfo           imagehash           pycodestyle         werkzeug
# abc                 imageio             pycosat             whatthepatch
# absl                imagesize           pycparser           wheel
# adodbapi            imaplib             pyct                widgetsnbextension
# afxres              imblearn            pycurl              win2kras
# aifc                imghdr              pydantic            win32api
# aiobotocore         importlib           pydantic_core       win32clipboard
# aiohappyeyeballs    importlib_metadata  pydeck              win32com
# aiohttp             importlib_resources pydispatch          win32con
# aioitertools        incremental         pydoc               win32console
# aiosignal           inflect             pydoc_data          win32cred
# alabaster           inflection          pydocstyle          win32crypt
# altair              iniconfig           pyexpat             win32cryptcon
# anaconda_anon_usage inspect             pyflakes            win32ctypes
# anaconda_catalogs   intake              pygame              win32event
# anaconda_cloud_auth intervaltree        pygments            win32evtlog
# anaconda_navigator  io                  pylab               win32evtlogutil
# anaconda_project    ipaddress           pylint              win32file
# annotated_types     ipykernel           pylint_venv         win32gui
# antigravity         ipykernel_launcher  pyls_spyder         win32gui_struct
# anyio               ipython_genutils    pylsp               win32help
# appdirs             ipywidgets          pylsp_black         win32inet
# archspec            isapi               pylsp_jsonrpc       win32inetcon
# argon2              isort               pyodbc              win32job
# argparse            isympy              pyparsing           win32lz
# array               itemadapter         pytest              win32net
# arrow               itemloaders         pythoncom           win32netcon
# ast                 itertools           pythonjsonlogger    win32pdh
# astroid             itsdangerous        pytoolconfig        win32pdhquery
# astropy             jedi                pytz                win32pdhutil
# astropy_iers_data   jellyfish           pyviz_comms         win32pipe
# asttokens           jinja2              pywin               win32print
# astunparse          jmespath            pywin32_bootstrap   win32process
# async_lru           joblib              pywin32_testutil    win32profile
# asyncio             json                pywintypes          win32ras
# atexit              json5               pywt                win32rcparser
# atomicwrites        jsonpatch           qdarkstyle          win32security
# attr                jsonpointer         qstylizer           win32service
# attrs               jsonschema          qtawesome           win32serviceutil
# audioop             jsonschema_specifications qtconsole           win32timezone
# autocommand         jupyter             qtpy                win32trace
# automat             jupyter_client      queue               win32traceutil
# autopep8            jupyter_console     queuelib            win32transaction
# babel               jupyter_core        quopri              win32ts
# backports           jupyter_events      random              win32ui
# base64              jupyter_lsp         rasutil             win32uiole
# bcrypt              jupyter_server      re                  win32verstamp
# bdb                 jupyter_server_terminals referencing         win32wnet
# binaryornot         jupyterlab          regcheck            win_inet_pton
# binascii            jupyterlab_plotly   regex               winerror
# binstar_client      jupyterlab_pygments regutil             winioctlcon
# bisect              jupyterlab_server   repo_cli            winnt
# black               jupyterlab_widgets  reprlib             winperf
# blackd              jwt                 requests            winpty
# bleach              keras               requests_file       winreg
# blib2to3            keyring             requests_toolbelt   winsound
# blinker             keyword             rfc3339_validator   winxpgui
# bokeh               kiwisolver          rfc3986_validator   winxptheme
# boltons             lazy_loader         rich                wordcloud
# botocore            lazy_object_proxy   rlcompleter         wrapt
# bottleneck          lckr_jupyterlab_variableinspector rope                wsgiref
# brotli              lib2to3             rpds                xarray
# bs4                 libarchive          rtree               xdrlib
# builtins            libmambapy          ruamel_yaml         xlwings
# bz2                 lief                runpy               xlwingsjs
# cProfile            linecache           s3fs                xml
# cachetools          linkify_it          sched               xmlrpc
# calendar            llvmlite            scipy               xxlimited
# certifi             lmdb                scrapy              xxlimited_35
# cffi                locale              seaborn             xxsubtype
# cgi                 locket              secrets             xyzservices
# cgitb               logging             select              yaml
# chardet             lxml                selectors           yapf
# charset_normalizer  lz4                 semver              yapf_third_party
# chunk               lzma                send2trash          yapftests
# clang               mailbox             service_identity    yarl
# click               mailcap             servicemanager      ydata_profiling
# cloudpickle         markdown            setuptools          yfinance
# cmath               markdown_it         shelve              zict
# cmd                 markupsafe          shlex               zipapp
# code                marshal             shutil              zipfile
# codecs              math                signal              zipimport
# codeop              matplotlib          sipbuild            zipp
# collections         matplotlib_inline   site                zlib
# colorama            mccabe              six                 zmq
# colorcet            mdit_py_plugins     skimage             zoneinfo
# colorsys            mdurl               sklearn             zope
# comm                menuinst            slugify             zstandard
# commctrl            mimetypes           smart_open
# compileall          minify_html         smmap
# concurrent          missingno           smtplib
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %% [markdown]
# # Loops in Python

# %%
# Need for loops
# - While Loop
# - For Loop

# %%
# While loop example -> program to print the table
# Program -> Sum of all digits of a given number
# Program -> keep accepting numbers from users till he/she enters a 0 and then find the avg

# %%
number = int(input('enter the number'))

i = 1

while i<11:
  print(number,'*',i,'=',number * i)
  i += 1
# Out:
# enter the number 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
# while loop with else 

x = 1

while x < 3:
  print(x)
  x += 1

else:
  print('limit crossed')
# Out:
# 1
# 2
# limit crossed

# %%
# Guessing game

# generate a random integer between 1 and 100
import random
jackpot = random.randint(1,100)

guess = int(input('guess karo'))
counter = 1
while guess != jackpot:
  if guess < jackpot:
    print('galat!guess higher')
  else:
    print('galat!guess lower')

  guess = int(input('guess karo'))
  counter += 1

else:
  print('correct guess')
  print('attempts',counter)
# Out:
# guess karo 5
# galat!guess higher
# guess karo 88
# galat!guess higher
# guess karo 99
# galat!guess lower
# guess karo 92
# galat!guess lower
# guess karo 91
# galat!guess lower
# guess karo 90
# correct guess
# attempts 6

# %%
 # For loop demo

for i in {1,2,3,4,5}:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Program
#- The current population of a town is 10000. The population of the town is increasing at the rate of 10% per year. 
#You have to write a program to find out the population at the end of each of the last 10 years.

# %%
curr_pop = 10000

for i in range(10,0,-1):
  print(i,curr_pop)
  curr_pop = curr_pop / 1.1
# Out:
# 10 10000
# 9 9090.90909090909
# 8 8264.462809917353
# 7 7513.148009015775
# 6 6830.134553650703
# 5 6209.213230591548
# 4 5644.739300537771
# 3 5131.5811823070635
# 2 4665.07380209733
# 1 4240.976183724845
